# %% [markdown]
# # Two Dimensional Data Worksheet
#
# This worksheet focuses on manipulating two dimensional data using R.

# %%
# install.packages("devtools")
# devtools::install_github("hadley/tidyverse")
library(tidyverse)
knitr::opts_chunk$set(echo=FALSE)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %% [markdown]
# Create a dataframe called `twitter` from the CSV file
#
# _Note if this is breaking your machine there is a smaller data set in the data file called twitter1-small.csv_

# %%
twitter <- read_csv( '../../Data/twitter1.csv')
# Out:
# Parsed with column specification:
# cols(
#   `Primary Key` = col_integer(),
#   Service = col_character(),
#   Term = col_character(),
#   Username = col_character(),
#   Name = col_character(),
#   Update = col_character(),
#   Location = col_character(),
#   URL = col_character(),
#   Friends = col_integer(),
#   Followers = col_integer(),
#   `Time(PDT)` = col_character(),
#   City = col_character(),
#   `State/Region` = col_character(),
#   Country = col_character(),
#   Metro = col_character(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )

# %% [markdown]
# ## Exercise 1
#
# Using the twitter data frame, count the appearances of each `Username`, get the top 10 active users and output the sorted result.
#
# 1. Start with `dplyr::count` on `Username`
# 2. Grab the top 10 with `dplyr_top_n`
# 3. sort with `dplyr::arrange`, can make it descending by wrapping the sort variable with `desc()`

# %%
twitter %>% count(Username) %>% top_n(10) %>% arrange(desc(n))
# Out:
# Selecting by n
#    Username        n
# 1  HoolohaTube     155
# 2  Rasu24          150
# 3  HOOLOHASPORT    126
# 4  mahboobali3     119
# 5  EminemsRealWife 116
# 6  byezekiel        89
# 7  MyrtleMuelr      83
# 8  LucindaFischer   79
# 9  DebraRichayd     77
# 10 JeanieNoble      70

# %% [markdown]
# ## Exercise 2
# Using the original twitter data set, create a second DataFrame called `twitterSummary` which contains the following columns:
#
# * Username
# * Friends
# * Followers
#
# Next add a column called `ffratio` which contains the ratio of friends to followers.  Show the first few lines.

# %%
# classic method:
# twitterSummary <- twitter[ ,c('Username', 'Friends', 'Followers')]
# twitterSummary$ffratio <- twitterSummary$Friends / twitterSummary$Followers
# head(twitterSummary)

# with tidyverse
twitterSummary <- twitter %>% 
  select(Username, Friends, Followers) %>% 
  mutate(ffratio = Friends / Followers)
# it will automatically show it pretty
twitterSummary
# Out:
#        Username        Friends Followers ffratio
# 1      _prettybrown     1042    1538     0.6775033
# 2      CarlyManning24    278     304     0.9144737
# 3      madzLuvzLakers    619    1039     0.5957652
# 4      _AyyJayy          203     204     0.9950980
# 5      Akeemoneale       165      27     6.1111111
# 6      demetricel          0       0           NaN
# 7      MrKooman          203    6001     0.0338277
# 8      bri_quebengco      28      30     0.9333333
# 9      Lboogs82          212     253     0.8379447
# 10     orccs              32      13     2.4615385
# 11     prettyiddy         33      38     0.8684211
# 12     N8_Anderson        56      27     2.0740741
# 13     2nd_Nature        151      80     1.8875000
# 14     Alixebaby          98     196     0.5000000
# 15     MrBAAD            187     143     1.3076923
# 16     MplsGoddess       119     228     0.5219298
# 17     Nana_Osei          72     121     0.5950413
# 18     kristiblack09     219      54     4.0555556
# 19     iam_KEYZIE        926     426     2.1737089
# 20     CarlsJr         13170   12342     1.0670880
# 21     parkkv             75      99     0.7575758
# 22     Boomquiesha_J     374     169     2.2130178
# 23     boujeebit         153     215     0.7116279
# 24     Bamadeb1971       118      27     4.3703704
# 25     itsRinaaa         449     276     1.6268116
# 26     rjaeflores        144      98     1.4693878
# 27     ayitsCATCHY        85      60     1.4166667
# 28     Apiffany          143     154     0.9285714
# 29     angelovalenteam    44      55     0.8000000
# 30     YoungCharmCity    682    1423     0.4792691
# ⋮      ⋮               ⋮       ⋮         ⋮
# 292980 bleacherbunny   107       65       1.64615385
# 292981 Nancy09_08_77   194      218       0.88990826
# 292982 mario_ballstar  114      180       0.63333333
# 292983 k_saaby          22       10       2.20000000
# 292984 gkindred1       100      166       0.60240964
# 292985 UndeniableOne   277      421       0.65795724
# 292986 TheDeuce222     101        7      14.42857143
# 292987 MissStartastic   85      132       0.64393939
# 292988 c_scotty        517      270       1.91481481
# 292989 quobae           93      106       0.87735849
# 292990 FooleyMcGooley   71       69       1.02898551
# 292991 SabrinaFTW27     68      101       0.67326733
# 292992 Roosevelt60       7       26       0.26923077
# 292993 I_Am_MissJax    196      432       0.45370370
# 292994 jojobiteng       62       53       1.16981132
# 292995 PETEROKK        171       42       4.07142857
# 292996 LucyLuvsSports  145       87       1.66666667
# 292997 calvin_chandraa  99       80       1.23750000
# 292998 gottaluvbieber_ 995     1755       0.56695157
# 292999 Larry_L23        66       51       1.29411765
# 293000 scotland3         2        1       2.00000000
# 293001 scotland3         2        1       2.00000000
# 293002 getitboizknucc   82       97       0.84536082
# 293003 jassy__          89      124       0.71774194
# 293004 asktwitqa        50      675       0.07407407
# 293005 estellegaelle     0        0              NaN
# 293006 deltabeautee     89       57       1.56140351
# 293007 tombokan         70       47       1.48936170
# 293008 MariaFCB        354       57       6.21052632
# 293009 debrakay23      496      373       1.32975871

# %% [markdown]
# ## Exercise 3
#
# In the `data` folder, there is file called `studentData.csv` consisting of students and test scores.  Write a script which calculates each students' average test score and adds that as a column to the DataFrame.
#
# The first person to tell me which student has the highest average test score, and what it is wins something.

# %% [markdown]
# ## Exercise 4
# Using the twitter data, find all the users with Facebook accounts and create a new column called `FacebookID` which contains the users' Facebook ID.  As you can see in the URL below, a user's Facebook ID can be found in the URL column, http://www.facebook.com/profile.php?id=5141860.  Extract this the ID. Don't forget to remove all the invalid or empty IDs.
#
# 1. Use the Function supplied to extract "?id=<numbers>" from the URL
#     + Note the function does not filter for facebook, so you will have to prefilter the data for facebook, try using `dplyr::filter` with `grepl` inside the function.
# 2. Once complete, filter out the data where the FacebookID is not NA (`!is.na()`).
#
# _Note: there are a lot of [ways to pull a substring from a string](http://stackoverflow.com/questions/2192316/extract-a-regular-expression-match-in-r-version-2-10):_

# %%
library(stringr) # do you have this installed?
getfacebook <- function(x) {
    # this pivots on grepl (logical grep returns TRUE or FALSE)
    # if it contains facebook, then split on ?id=, grabbing the remaining text
    # else return NA
    ifelse(grepl('\\?id=\\d+', x), 
           str_extract(str_extract(x, "\\?id=\\d+"), "\\d+"),
           NA)
}
foo <- twitter %>% 
  ## filter for all facebook to reduce computations later
  filter(grepl('facebook.com', URL)) %>% 
  ## run all the URLS through the above function
  mutate(FacebookID = getfacebook(URL))
foo %>% select(URL, FacebookID) %>% filter(!is.na(FacebookID))
# Out:
#      URL
# 1    http://www.facebook.com/home.php?#!/profile.php?id=100000926596946&ref=profile
# 2    http://www.facebook.com/profile.php?id=514186015&ref=profile#!/profile.php?id=514186015&ref=ts
# 3    http://http://www.facebook.com/?ref=home#!/profile.php?id=506234142&ref=profile
# 4    http://www.facebook.com/home.php#/profile.php?id=1707568551&ref=name
# 5    http://www.facebook.com/home.php?#/profile.php?id=38403445&ref=name
# 6    http://www.facebook.com/profile.php?id=1060743307&ref=profile
# 7    http://www.facebook.com/#!/profile.php?id=702012065
# 8    http://www.facebook.com/#!/profile.php?id=1701903898&ref=profile
# 9    http://www.facebook.com/profile.php?id=1567050070&ref=profile
# 10   http://www.facebook.com/profile.php?id=100000382878368
# 11   http://www.facebook.com/home.php?#!/profile.php?id=680380986
# 12   http://www.facebook.com/home.php?#!/profile.php?id=1572150134
# 13   http://www.facebook.com/#!/profile.php?id=506618288&ref=profile
# 14   http://www.facebook.com/#!/profile.php?id=1049906341&ref=profile
# 15   http://www.facebook.com/profile.php?id=551167346
# 16   http://www.facebook.com/home.php?#!/profile.php?id=505690778
# 17   http://www.facebook.com/profile.php?id=668316163&ref=profile
# 18   http://www.facebook.com/profile.php?id=1114260328&ref=name
# 19   http://www.facebook.com/home.php?#!/profile.php?id=1662884015
# 20   http://www.facebook.com/?ref=home#!/profile.php?id=1536068481
# 21   http://www.facebook.com/#!/profile.php?id=100000557829983&ref=profile
# 22   http://http:/http://www.facebook.com/profile.php?id=100000586755800&ref=profile
# 23   http://www.facebook.com/nicholas.williams#!/profile.php?id=1089672962
# 24   http://www.facebook.com/profile.php?id=1722279140
# 25   http://www.facebook.com/profile.php?id=300100198#!/profile.php?id=18904683&ref=profile
# 26   http://www.facebook.com/home.php?#!/profile.php?id=69401272&ref=profile
# 27   http://www.facebook.com/profile.php?id=507390769&ref=profile
# 28   http://www.facebook.com/profile.php?id=100000735063805
# 29   http://www.facebook.com/profile.php?id=533545683&amp;ref=profile
# 30   http://www.facebook.com/profile.php?id=100000468175846
# ⋮    ⋮
# 4761 http://www.facebook.com/home.php?#/profile.php?id=1622332379&ref=profile
# 4762 http://www.facebook.com/profile.php?id=525134685&ref=profile
# 4763 http://www.facebook.com/?ref=mb&sk=messages#!/profile.php?id=1218392677&ref=profile
